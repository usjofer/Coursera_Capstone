# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
address = '316 Lafayette St, New York City, NY 10012'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of New York City are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of New York City are 40.7254535652174, -73.9951589130435.

# %%
#load FB access key
import yaml
FB_CONFIG_FILE = 'FB.env'
with open(FB_CONFIG_FILE, 'r') as config_file:
    config = yaml.load(config_file, Loader=yaml.BaseLoader)

# set parameters for FourSquare API calls
fb_access = config['FB']['access_token']
radius = 1000 # 1KM radius
limit = 5000 # 1K result limit

# %%
def fb_getNearbyVenues(coords, categoryID='', q_name='',radius=500 ):
    venues_list=[]
    for lat, lng in coords:
        #print(q_name)
            
        # create the API request URL
        url = ('https://graph.facebook.com/v3.2/search?type=place&center={},{},&distance={}'
#               '&categories={}'
               '&q={}'
               '&fields=name,checkins,location,category_list,engagement,overall_star_rating,rating_count'
               '&limit={}&access_token={}'
        ).format(
            lat, 
            lng, 
            radius,
#            categoryID,
            q_name,
            limit,
            fb_access
        )
            
        # make the GET request
#        print("URL:"+url)
        results = requests.get(url).json()["data"]
#        print(results)
        # return only relevant information for each nearby venue
        venues_list.append([(
            v['id'],
            v['name'], 
            v['location']['latitude'], 
            v['location']['longitude'],  
#            ','.join
            list(category['name'] for category in v['category_list']),
            v['engagement']['count'],
            v['checkins']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = [ 
                  'Venue ID',
                  'Venue Name', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category',
                  'Likes',
                  'Checkins']
    
    return(nearby_venues)

# %%
import math
#get geo coord shift by distance
def shift_coord(lat,lon, dist,bearing):
    R = 6371.0088 #Radius of the Earth
    brng = math.radians(bearing)


    lat1 = math.radians(lat) #lat point converted to radians
    lon1 = math.radians(lon) #long point converted to radians

    lat2 = math.asin( math.sin(lat1)*math.cos(dist/R) +
    math.cos(lat1)*math.sin(dist/R)*math.cos(brng))

    lon2 = lon1 + math.atan2(math.sin(brng)*math.sin(dist/R)*math.cos(lat1),
             math.cos(dist/R)-math.sin(lat1)*math.sin(lat2))

    lat2 = math.degrees(lat2)
    lon2 = math.degrees(lon2)

    return (lat2, lon2)
#build coord grid
def cgrid(latitude, longitude, distance, legs):
    ab=[]
    for i in range(-legs,legs):
        if i==0:
            ab.append([latitude, longitude])
            continue
        #ab.append(shift_coord(latitude, longitude, distance*i, j) for j in (0,90,180,270))
        for j in (0,90,180,270):
            ab.append(shift_coord(latitude, longitude, distance*i, j))
        #ab.append(bb)    
    return ab

# %%
print("Coord grid for location "+str(latitude)+','+str(longitude))
coords =cgrid(latitude, longitude, 0.25, 2) 
print(coords)
# Out:
# Coord grid for location 40.7254535652174,-73.9951589130435
# [(40.72095696339877, -73.9951589130435), (40.72545341331191, -74.00109232208771), (40.729950167036016, -73.9951589130435), (40.72545341331191, -73.9892255039993), (40.72320526430809, -73.9951589130435), (40.72545352724103, -73.998125617569), (40.72770186612671, -73.9951589130435), (40.72545352724103, -73.992192208518), [40.7254535652174, -73.9951589130435], (40.72770186612671, -73.9951589130435), (40.72545352724103, -73.992192208518), (40.72320526430809, -73.9951589130435), (40.72545352724103, -73.998125617569)]

# %%
fb_cat_food='["FOOD_BEVERAGE"]'
#[(latitude, longitude)]
df_coffee = fb_getNearbyVenues([(latitude, longitude)], categoryID='',q_name='coffee',radius=3000)
df_coffee
# Out:
#              Venue ID                                  Venue Name  \
# 0     188174614578929                       Gasoline Alley Coffee
# 1    1153183334863823                           Coffee 'n Clothes
# 2     167155753349004                                  Kaffe 1668
# 3   10150160592938090                                 Coffee Shop
# 4     174894656545641                 OddFellows Ice Cream Nolita
# 5    1488169154738884                     Coffee Project New York
# 6    1783058001956701                                Think Coffee
# 7     590687424277706                                   Starbucks
# 8     191414257565217                                  Caffe Roma
# 9     169967663018216                             Grey Dog Coffee
# 10   1805355666455386                                Think Coffee
# 11   1423074811282455               The Coffee Shop, Bo. Barretto
# 12    463044183789165                        Andrew's Coffee Shop
# 13    242346189122812                   Stumptown Coffee Roasters
# 14    104930869549960                           Best Bagel Coffee
# 15   1076282905798395                        Ludlow Coffee Supply
# 16   2019078474822325                          Joe Coffee Company
# 17    226355768205432    Teras Rumah Ditemani Good Day Ice Coffee
# 18    115627791793313                        Landmark Coffee Shop
# 19   1718876888337306                                Birch Coffee
# 20   1288981564516404                           CaffeBene Tribeca
# 21    943912295655662                              Kobrick Coffee
# 22    304751679578437                Stumptown Coffee @ Ace Hotel
# 23    506002819741858                              787 Coffee Co.
# 24    212444355442237                             Gregorys Coffee
# 25   1168170503254243                                 Idea Coffee
# 26    148619982415898                        Caffe Bene NYC Ktown
# 27    807023522992863                           قرفه Coffee Break
# 28    277779773123892                              Ralph's Coffee
# 29    225014604681247                         Veselka Coffee Shop
# 30    498785087320101                           Sawada Coffee NYC
# 31   1141274942571825                                   Starbucks
# 32    286511164847757                            Gregory's Coffee
# 33    188930192006893             Brooklyn Bagel & Coffee Company
# 34   1214515968576710                                   Starbucks
# 35   1185068598279875                                Think Coffee
# 36   1018058964879937                The New York Coffee Festival
# 37    312139936235652                         Laughing Man Coffee
# 38    342844112494234           Brooklyn Bagel and Coffee Company
# 39    135316363179031                              Ground Support
# 40    192404884190745                                Grace Street
# 41   2000914306802169                     Variety Coffee Roasters
# 42   1838403336448381                                Think Coffee
# 43    119708552107174                          Blue Bottle Coffee
# 44    529185547421790                       Intelligentsia Coffee
# 45    242538899776406                                PAPER coffee
# 46   1167689853358044                                Think Coffee
# 47   1672855419670069                             Gregorys Coffee
# 48    317292062263595                          Blue Bottle Coffee
# 49    211309412300037                              Prodigy Coffee
# 50   1255675617860555                                Think Coffee
# 51    830685756983374                               Café Integral
# 52    499921947062178                          Blue Bottle Coffee
# 53  10152586926778043                        Irving Farm New York
# 54    394959207319825                        Toby's Estate Coffee
# 55    220814331685610              City of Saints Coffee Roasters
# 56   1798620147103077                 Irving Farm Coffee Roasters
# 57  10150228731735605                                 Cafe Grumpy
# 58    363805200456709                                   Starbucks
# 59    193524860716890                                Laughing Man
# 60   1572805156281750                 Lower East Side Coffee Shop
# 61    678329802231723                           Third Rail Coffee
# 62    940199356017746                   The Lazy Llama Coffee Bar
# 63   1422082748018805                            Underline Coffee
# 64   1631974043548920                              Bluestone Lane
# 65    162696160949134                          Blue Bottle Coffee
# 66   1657620437855281                             Gregorys Coffee
# 67   1545190815722419      Toby's Estate Coffee 44 Charles Street
# 68    169318080251655                          Blue Bottle Coffee
# 69  10150226699489468                           Third Rail Coffee
# 70    718990138243878                                   Starbucks
# 71    306647206585237                           Kaigo Coffee Room
# 72    231843357299425                   Central Perk Coffee House
# 73    218350925484410                          Joe Coffee Company
# 74   1353038784722221                                   Starbucks
# 75    147175569108983                            Saltwater Coffee
# 76    257788897571808                       Roasting Plant Coffee
# 77   1111694002236785                      Bell's Coffee & Design
# 78   1294178957288203                                   Starbucks
# 79    196021720444606                          Joe Coffee Company
# 80    460169510855720                       Gregory's Coffee 30th
# 81   1024759964284008                                Birch Coffee
# 82    200714116638251                                    Grounded
# 83    943120662507665                              Bluestone Lane
# 84   1002206293133001                                Rebel Coffee
# 85   1306479879373911                                   Starbucks
# 86   1056408647753601                                   Starbucks
# 87    206440846043691                Porto Rico Importing Company
# 88    994709373920043                                   Starbucks
# 89   1206833492677369                                   Starbucks
# 90    130620554013382                         Black Fox Coffee Co
# 91    512678685477201                              Le Cafe Coffee
# 92  10150165427034464                   5C Cafe & Cultural Center
# 93   1861688053859758                             Gregorys Coffee
# 94    598159320242094  Counter Culture Coffee Training Center NYC
#
#     Venue Latitude  Venue Longitude  \
# 0        40.725420       -73.994820
# 1        40.726620       -73.994350
# 2        40.715410       -74.011030
# 3        40.736440       -73.990990
# 4        40.724580       -73.994450
# 5        40.726990       -73.989220
# 6        40.725420       -73.992550
# 7        40.751274       -73.990887
# 8        40.720360       -73.996760
# 9        40.723047       -73.995806
# 10       40.728207       -73.995365
# 11       40.750641       -74.003736
# 12       40.751695       -73.989917
# 13       40.732830       -73.997940
# 14       40.752180       -73.991100
# 15       40.721670       -73.987270
# 16       40.733297       -74.000566
# 17       40.742931       -73.991163
# 18       40.719990       -73.998660
# 19       40.743623       -73.986346
# 20       40.721030       -74.004440
# 21       40.740450       -74.005510
# 22       40.745590       -73.987950
# 23       40.726290       -73.983860
# 24       40.747728       -73.989083
# 25       40.744660       -73.987550
# 26       40.748070       -73.987380
# 27       40.702370       -74.011330
# 28       40.740108       -73.990857
# 29       40.729620       -73.987800
# 30       40.717973       -74.001760
# 31       40.718333       -74.000057
# 32       40.706110       -74.012850
# 33       40.731040       -73.993220
# 34       40.718985       -74.002691
# 35       40.738150       -73.984000
# 36       40.741142       -73.983742
# 37       40.717590       -74.010860
# 38       40.746078       -73.997598
# 39       40.724290       -74.001980
# 40       40.747720       -73.986580
# 41       40.745220       -73.994630
# 42       40.738310       -73.995510
# 43       40.710638       -74.012425
# 44       40.745960       -74.005030
# 45       40.746310       -73.989480
# 46       40.733010       -73.989790
# 47       40.727670       -74.007080
# 48       40.716548       -74.008966
# 49       40.730200       -74.003260
# 50       40.739500       -74.002940
# 51       40.720352       -73.999734
# 52       40.742500       -74.007180
# 53       40.736716       -73.986817
# 54       40.740160       -73.990830
# 55       40.731200       -73.989930
# 56       40.729670       -73.998780
# 57       40.742670       -73.998310
# 58       40.718262       -74.007385
# 59       40.717310       -74.010160
# 60       40.730380       -73.980680
# 61       40.729750       -73.987060
# 62       40.723470       -73.988660
# 63       40.746292       -74.006065
# 64       40.730009       -74.002855
# 65       40.734030       -73.992520
# 66       40.705200       -74.007090
# 67       40.734900       -74.002280
# 68       40.719270       -73.985090
# 69       40.729940       -73.999590
# 70       40.741679       -73.980780
# 71       40.718689       -74.000516
# 72       40.729999       -73.986408
# 73       40.698673       -73.994358
# 74       40.712224       -74.008243
# 75       40.730330       -73.984030
# 76       40.736768       -74.000954
# 77       40.722950       -74.004562
# 78       40.736968       -73.996549
# 79       40.735004       -73.993322
# 80       40.748405       -73.992813
# 81       40.710891       -74.005749
# 82       40.737990       -74.003445
# 83       40.730104       -73.990307
# 84       40.737840       -74.004750
# 85       40.733001       -73.999625
# 86       40.748066       -73.989288
# 87       40.729527       -74.001679
# 88       40.703275       -74.014045
# 89       40.729354       -73.987357
# 90       40.706512       -74.007717
# 91       40.735750       -73.992590
# 92       40.722730       -73.979660
# 93       40.740970       -73.985570
# 94       40.720410       -73.996270
#
#                                        Venue Category  Likes  Checkins
# 0                           [Coffee Shop, Restaurant]   1746      3058
# 1                                     [Internet Cafe]   1568        88
# 2                                       [Coffee Shop]    683      6154
# 3                               [American Restaurant]   8092     24939
# 4                       [Coffee Shop, Ice Cream Shop]     52       412
# 5                                       [Coffee Shop]   1779      3765
# 6                     [Coffee Shop, Bakery, Tea Room]     59       783
# 7                                       [Coffee Shop]    225      2542
# 8                                       [Coffee Shop]   1361     13424
# 9            [Breakfast & Brunch Restaurant, Caterer]    265      5287
# 10                  [Coffee Shop, Restaurant, Bakery]     83      1623
# 11                                      [Coffee Shop]     21       392
# 12                 [American Restaurant, Diner, Cafe]   3490     18277
# 13                                      [Coffee Shop]   1187      7248
# 14                                      [Coffee Shop]   1197     14351
# 15                                            [Hotel]     24       332
# 16                                      [Coffee Shop]      9       224
# 17                                     [Just For Fun]     15      2471
# 18                                             [Cafe]     83      2032
# 19                                      [Coffee Shop]    215      8732
# 20  [Coffee Shop, Dessert Shop, Breakfast & Brunch...     32       477
# 21                                      [Coffee Shop]    250      3412
# 22                               [Coffee Shop, Hotel]    293      6735
# 23                                      [Coffee Shop]    256       188
# 24                                      [Coffee Shop]   6141     10794
# 25                                      [Coffee Shop]    203      1236
# 26                  [Coffee Shop, Restaurant, Lounge]     63       828
# 27                                        [Community]  28178        82
# 28                                      [Coffee Shop]     23        51
# 29                                       [Restaurant]      7       193
# 30                                      [Coffee Shop]     12        35
# 31                                      [Coffee Shop]   2146     12289
# 32                                      [Coffee Shop]    320      2273
# 33                     [Bakery, Fast Food Restaurant]      0       116
# 34                                      [Coffee Shop]    535      9652
# 35                  [Coffee Shop, Restaurant, Bakery]     17       400
# 36                                            [Event]   5881      2417
# 37                                      [Coffee Shop]    195        51
# 38                                       [Restaurant]    473      9175
# 39                                      [Coffee Shop]    920      5324
# 40       [Coffee Shop, Dessert Shop, Bubble Tea Shop]   1841     20242
# 41                                      [Coffee Shop]     62      2933
# 42                                      [Coffee Shop]     22       375
# 43                                      [Coffee Shop]     51       943
# 44                               [Coffee Shop, Hotel]     40       427
# 45                                      [Coffee Shop]      5        95
# 46                    [Coffee Shop, Bakery, Tea Room]     38       629
# 47                                      [Coffee Shop]     68       362
# 48                                      [Coffee Shop]      2        59
# 49                                      [Coffee Shop]    617      1579
# 50               [Coffee Shop, Bakery, Internet Cafe]     41       704
# 51                                      [Coffee Shop]   1801      1355
# 52                                      [Coffee Shop]     29       923
# 53                                      [Coffee Shop]   5319      6705
# 54                                      [Coffee Shop]    215      2018
# 55                          [Restaurant, Coffee Shop]     11       170
# 56                                      [Coffee Shop]      2        36
# 57                          [Coffee Shop, Restaurant]   6502      7353
# 58                                      [Coffee Shop]     93      3223
# 59                [Coffee Shop, Charity Organization]  44994      5284
# 60                                      [Coffee Shop]     39      1094
# 61                                      [Coffee Shop]     48      1034
# 62                                 [Cafe, Restaurant]    130       440
# 63                                      [Coffee Shop]    443      1649
# 64                                      [Coffee Shop]    207       978
# 65                                      [Coffee Shop]    229       295
# 66                                      [Coffee Shop]     61       329
# 67                                      [Coffee Shop]    217      2048
# 68                                      [Coffee Shop]     26       456
# 69                                      [Coffee Shop]   3336      2927
# 70                                      [Coffee Shop]     85      2196
# 71                                      [Coffee Shop]      6        67
# 72                                      [Coffee Shop]    190       191
# 73                                      [Coffee Shop]     10       174
# 74                                      [Coffee Shop]    524     11423
# 75                                      [Coffee Shop]    296       222
# 76                                      [Coffee Shop]   2821      3326
# 77                           [Coffee Shop, Gift Shop]    356       250
# 78                                      [Coffee Shop]    467      5371
# 79                                      [Coffee Shop]   4614      1335
# 80                                      [Coffee Shop]     79       567
# 81                                      [Coffee Shop]     38       506
# 82                                      [Coffee Shop]   2724      4808
# 83                                      [Coffee Shop]     69       846
# 84                                      [Coffee Shop]    185       461
# 85                                      [Coffee Shop]    227      3475
# 86                                      [Coffee Shop]    207      5919
# 87             [Coffee Shop, Specialty Grocery Store]   1548      2461
# 88                                      [Coffee Shop]     90      3072
# 89                                      [Coffee Shop]    259      2840
# 90                                      [Coffee Shop]    463      1053
# 91                  [Coffee Shop, Restaurant, Bakery]   3568       683
# 92  [Coffee Shop, Jazz & Blues Club, Live Music Ve...    497       584
# 93                                      [Coffee Shop]     57       287
# 94                                      [Coffee Shop]    198       550

# %%
#df_coffe2 = fb_getNearbyVenues([(latitude, longitude)], categoryID='',q_name='coffee',radius=3000)
#df_coffe2["Venue Category"].where(
s = df_coffe2.iloc[3]["Venue Category"]
print(s)
# Out:
# ['American Restaurant']

# %%
df_dd = fb_getNearbyVenues([(latitude, longitude)], categoryID='',q_name='dunkin',radius=3000)

# %%
# create map of New York using latitude and longitude values
map_newyork = folium.Map(location=[latitude, longitude], zoom_start=15)
chain_color = { "Starbucks":"green","DD":"purple","Other":"blue"}

# add markers to map
for lat, lng, venue, checkins in zip(df_coffee['Venue Latitude'], df_coffee['Venue Longitude'], df_coffee['Venue Name'], df_coffee['Checkins']):
    label = venue+", Checkins:"+str(checkins)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color="blue",#chain_color.get(chain),
        fill=True,
        fill_color="blue",#chain_color.get(chain),
        fill_opacity=0.7,
        parse_html=False).add_to(map_newyork)  
    
map_newyork
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#import string
s="{'name': 'Champion Pizza', 'checkins': 10834, 'location': {'city': 'New York', 'country': 'United States', 'latitude': 40.721614, 'longitude': -73.997212, 'state': 'NY', 'street': '17 Cleveland place', 'zip': '10012'}, 'category_list': [{'id': '180256082015845', 'name': 'Pizza Place'}, {'id': '192803624072087', 'name': 'Fast Food Restaurant'}], 'engagement': {'count': 524634, 'social_sentence': '524K people like this.'}, 'rating_count': 0, 'id': '184927038672914'}"
s = s.replace("'",'"')
results = json.loads(s)
print(results["category_list"])
#cc = ','.join(category['name'] for category in results['category_list'])
cc = list(category['name'] for category in results['category_list'])
cc
# Out:
# [{'id': '180256082015845', 'name': 'Pizza Place'}, {'id': '192803624072087', 'name': 'Fast Food Restaurant'}]
# ['Pizza Place', 'Fast Food Restaurant']
